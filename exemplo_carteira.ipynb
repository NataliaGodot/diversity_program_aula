# %% [markdown]
# # Análise SELIC

# %%
import pandas as pd

df = pd.read_csv("carteira.csv")

print(df)
# Out:
#       Unnamed: 0        Data      Cota      Variação  fund_id            PL
# 0              0  2012-03-07  1.000000           0.0       26  4.500000e+05
# 1              1  2012-03-08  1.000347     0.0003475       26  4.501564e+05
# 2              2  2012-03-09  1.000670  0.0003227878       26  4.503017e+05
# 3              3  2012-03-12  1.001274  0.0006033955       26  1.800573e+06
# 4              4  2012-03-13  1.005240  0.0039611527       26  1.807706e+06
# ...          ...         ...       ...           ...      ...           ...
# 2462        2462  2021-12-27  4.164685      0.001449       26  4.448857e+08
# 2463        2463  2021-12-28  4.164019      -0.00016       26  4.451305e+08
# 2464        2464  2021-12-29  4.177355      0.003203       26  4.467309e+08
# 2465        2465  2021-12-30  4.172508      -0.00116       26  4.462443e+08
# 2466        2466  2021-12-31  4.166819     -0.001363       26  4.454459e+08
#
# [2467 rows x 6 columns]

# %%
df.plot(x="Data", y="Cota")
# Out:
# /home/natalia/miniconda3/envs/padrao/lib/python3.8/site-packages/pandas/plotting/_matplotlib/core.py:1235: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(xticklabels)
# <AxesSubplot:xlabel='Data'>

# %%
df.plot(x="Data", y="PL")
# Out:
# /home/natalia/miniconda3/envs/padrao/lib/python3.8/site-packages/pandas/plotting/_matplotlib/core.py:1235: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(xticklabels)
# <AxesSubplot:xlabel='Data'>

# %%
df["Cota"].max()
# Out:
# 4.20962379

# %%
df["Cota"].idxmax()
# Out:
# 2437

# %%
df.iloc[2437]
# Out:
# Unnamed: 0           2437
# Data           2021-11-22
# Cota              4.20962
# Variação         0.003702
# fund_id                26
# PL            4.37357e+08
# Name: 2437, dtype: object
